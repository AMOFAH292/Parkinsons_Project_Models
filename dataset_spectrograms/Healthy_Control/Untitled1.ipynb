# %%
import os
import librosa
import numpy as np
import matplotlib.pyplot as plt
import librosa.display

# Paths
INPUT_ROOT = "PARK_DATA"  # contains parkinson/ and healthy/
OUTPUT_ROOT = "dataset_spectrograms"
TARGET_DURATION = 5.0   # seconds
SR = 22050              # sampling rate for spectrogram
N_MELS = 128
IMG_SIZE = (224, 224)

os.makedirs(OUTPUT_ROOT, exist_ok=True)

def save_melspec(y, sr, out_path):
    mel = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=N_MELS)
    mel_db = librosa.power_to_db(mel, ref=np.max)

    plt.figure(figsize=(3, 3))
    librosa.display.specshow(mel_db, sr=sr, cmap="magma")
    plt.axis('off')
    plt.tight_layout()
    plt.savefig(out_path, dpi=100, bbox_inches='tight', pad_inches=0)
    plt.close()

for label in ["PD_segments", "HC_segments"]:
    input_dir = os.path.join(INPUT_ROOT, label)
    output_dir = os.path.join(OUTPUT_ROOT, label)
    os.makedirs(output_dir, exist_ok=True)

    for fname in os.listdir(input_dir):
        if not fname.endswith(".wav"):
            continue

        fpath = os.path.join(input_dir, fname)
        y, _ = librosa.load(fpath, sr=SR)

        # segment into 5-second windows
        window_len = int(TARGET_DURATION * SR)
        total_len = len(y)
        num_segments = total_len // window_len

        for i in range(num_segments):
            start = i * window_len
            end = start + window_len
            segment = y[start:end]

            # Skip segments shorter than 5 seconds
            if len(segment) < window_len:
                continue

            out_name = fname.replace(".wav", f"_{i}.png")
            out_path = os.path.join(output_dir, out_name)

            save_melspec(segment, SR, out_path)

print("✨ Spectrogram generation complete!")
# Out:
# ✨ Spectrogram generation complete!

# %% [markdown]
# ### DATA PREPROCESSING

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam

# Paths
DATASET_DIR = "dataset_spectrograms"  # contains Healthy_Control/ and Parkinson/
BATCH_SIZE = 16
IMG_SIZE = (224, 224)
EPOCHS = 10   # increase later if needed
LR = 1e-4

# Image data generator with augmentation for training
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
)

train_generator = train_datagen.flow_from_directory(
    DATASET_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='training',
    shuffle=True
)

val_generator = train_datagen.flow_from_directory(
    DATASET_DIR,
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='validation',
    shuffle=False
)
# Out:
# Found 516 images belonging to 2 classes.
# Found 128 images belonging to 2 classes.

# %% [markdown]
# ### TRAINING

# %%
# Load pretrained MobileNetV2 without top
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(*IMG_SIZE, 3))

# Freeze the base model
base_model.trainable = False

# Add custom classification head
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.2)(x)
predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile
model.compile(optimizer=Adam(LR), loss='binary_crossentropy', metrics=['accuracy'])

# Train
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# C:\Users\Felix\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 35s 926ms/step - accuracy: 0.5795 - loss: 0.7211 - val_accuracy: 0.5703 - val_loss: 0.7037
# Epoch 2/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 735ms/step - accuracy: 0.6202 - loss: 0.6563 - val_accuracy: 0.6016 - val_loss: 0.6473
# Epoch 3/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 766ms/step - accuracy: 0.6550 - loss: 0.6481 - val_accuracy: 0.5547 - val_loss: 0.6559
# Epoch 4/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 25s 789ms/step - accuracy: 0.6977 - loss: 0.5720 - val_accuracy: 0.6250 - val_loss: 0.6320
# Epoch 5/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 708ms/step - accuracy: 0.6977 - loss: 0.5722 - val_accuracy: 0.6406 - val_loss: 0.6230
# Epoch 6/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 28s 855ms/step - accuracy: 0.7461 - loss: 0.5393 - val_accuracy: 0.6641 - val_loss: 0.6359
# Epoch 7/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 891ms/step - accuracy: 0.7326 - loss: 0.5430 - val_accuracy: 0.6094 - val_loss: 0.6820
# Epoch 8/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 29s 870ms/step - accuracy: 0.7345 - loss: 0.5341 - val_accuracy: 0.6562 - val_loss: 0.6348
# Epoch 9/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 27s 820ms/step - accuracy: 0.7209 - loss: 0.5338 - val_accuracy: 0.6328 - val_loss: 0.6333
# Epoch 10/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 24s 730ms/step - accuracy: 0.7384 - loss: 0.5219 - val_accuracy: 0.6797 - val_loss: 0.6027

# %% [markdown]
# ### FIE TUNING

# %%
# Unfreeze some layers for fine-tuning
base_model.trainable = True
for layer in base_model.layers[:-50]:  # freeze early layers, fine-tune later layers
    layer.trainable = False

# Recompile for fine-tuning
model.compile(optimizer=Adam(LR/10), loss='binary_crossentropy', metrics=['accuracy'])

# Fine-tune
history_ft = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=EPOCHS
)
# Out:
# Epoch 1/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.4593 - loss: 1.2713 - val_accuracy: 0.6094 - val_loss: 0.6664
# Epoch 2/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.5097 - loss: 0.9063 - val_accuracy: 0.5859 - val_loss: 0.6899
# Epoch 3/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.6298 - loss: 0.6589 - val_accuracy: 0.5625 - val_loss: 0.6841
# Epoch 4/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 38s 1s/step - accuracy: 0.6996 - loss: 0.5692 - val_accuracy: 0.6250 - val_loss: 0.7081
# Epoch 5/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - accuracy: 0.6783 - loss: 0.5621 - val_accuracy: 0.6016 - val_loss: 0.7185
# Epoch 6/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - accuracy: 0.7267 - loss: 0.5422 - val_accuracy: 0.5859 - val_loss: 0.7757
# Epoch 7/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - accuracy: 0.7209 - loss: 0.5388 - val_accuracy: 0.6016 - val_loss: 0.7747
# Epoch 8/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - accuracy: 0.7539 - loss: 0.4762 - val_accuracy: 0.5781 - val_loss: 0.7542
# Epoch 9/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.7519 - loss: 0.4665 - val_accuracy: 0.5625 - val_loss: 0.7998
# Epoch 10/10
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.7791 - loss: 0.4564 - val_accuracy: 0.5703 - val_loss: 0.9310

# %% [markdown]
# ### YAMNET INITIALIZATION

# %%
# !pip install tensorflow tensorflow-hub
# Out:
# Requirement already satisfied: tensorflow in c:\users\felix\anaconda3\lib\site-packages (2.20.0rc0)
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Felix\AppData\Roaming\Python\Python313\site-packages\~-mpy'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Felix\anaconda3\Lib\site-packages\~ensorflow'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# label-studio 1.21.0 requires numpy<2.0.0,>=1.26.4, but you have numpy 2.3.5 which is incompatible.
# gradio 5.49.1 requires pillow<12.0,>=8.0, but you have pillow 12.0.0 which is incompatible.
# gradio 5.49.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 2.3.5 which is incompatible.
# streamlit 1.45.1 requires cachetools<6,>=4.0, but you have cachetools 6.2.2 which is incompatible.
# streamlit 1.45.1 requires packaging<25,>=20, but you have packaging 25.0 which is incompatible.
# streamlit 1.45.1 requires pillow<12,>=7.1.0, but you have pillow 12.0.0 which is incompatible.
# Collecting tensorflow-hub
#   Downloading tensorflow_hub-0.16.1-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\felix\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\felix\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\felix\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\felix\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\felix\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\felix\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\felix\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\felix\appdata\roaming\python\python313\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\felix\appdata\roaming\python\python313\site-packages (from tensorflow) (6.33.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\felix\appdata\roaming\python\python313\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\felix\appdata\roaming\python\python313\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\felix\appdata\roaming\python\python313\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\felix\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\felix\appdata\roaming\python\python313\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\felix\appdata\roaming\python\python313\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\felix\appdata\roaming\python\python313\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\felix\anaconda3\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\felix\anaconda3\lib\site-packages (from tensorflow) (3.11.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\felix\appdata\roaming\python\python313\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\felix\anaconda3\lib\site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\felix\anaconda3\lib\site-packages (from tensorflow) (0.5.3)
# Collecting numpy>=1.26.0 (from tensorflow)
#   Downloading numpy-2.3.5-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\felix\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\felix\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\felix\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\felix\appdata\roaming\python\python313\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\felix\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.8)
# Requirement already satisfied: pillow in c:\users\felix\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\felix\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\felix\appdata\roaming\python\python313\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.3)
# Collecting tf-keras>=2.14.1 (from tensorflow-hub)
#   Downloading tf_keras-2.20.1-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\felix\appdata\roaming\python\python313\site-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: rich in c:\users\felix\appdata\roaming\python\python313\site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in c:\users\felix\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\felix\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp313-cp313-win_amd64.whl.metadata (4.6 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\felix\appdata\roaming\python\python313\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\felix\appdata\roaming\python\python313\site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\felix\appdata\roaming\python\python313\site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\felix\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Downloading tensorflow_hub-0.16.1-py2.py3-none-any.whl (30 kB)
# Downloading numpy-2.3.5-cp313-cp313-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.0/12.8 MB 3.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.6/12.8 MB 3.4 MB/s eta 0:00:04
#    ------- -------------------------------- 2.4/12.8 MB 3.6 MB/s eta 0:00:03
#    --------- ------------------------------ 3.1/12.8 MB 3.7 MB/s eta 0:00:03
#    ------------ --------------------------- 3.9/12.8 MB 3.7 MB/s eta 0:00:03
#    -------------- ------------------------- 4.7/12.8 MB 3.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 5.5/12.8 MB 3.7 MB/s eta 0:00:02
#    ------------------ --------------------- 6.0/12.8 MB 3.6 MB/s eta 0:00:02
#    --------------------- ------------------ 6.8/12.8 MB 3.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 7.3/12.8 MB 3.5 MB/s eta 0:00:02
#    ------------------------- -------------- 8.1/12.8 MB 3.5 MB/s eta 0:00:02
#    --------------------------- ------------ 8.9/12.8 MB 3.5 MB/s eta 0:00:02
#    ----------------------------- ---------- 9.4/12.8 MB 3.4 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.8 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.0/12.8 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------ --- 11.8/12.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 3.4 MB/s eta 0:00:00
# Downloading tf_keras-2.20.1-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------ --------------------- 0.8/1.7 MB 3.6 MB/s eta 0:00:01
#    ------------------------ --------------- 1.0/1.7 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 2.7 MB/s eta 0:00:00
# Downloading tensorflow-2.20.0-cp313-cp313-win_amd64.whl (332.0 MB)
#    ---------------------------------------- 0.0/332.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/332.0 MB ? eta -:--:--
#    ---------------------------------------- 0.8/332.0 MB

#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    ---------- ----------------------------- 1/4 [tensorflow]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    -------------------- ------------------- 2/4 [tf-keras]
#    ------------------------------ --------- 3/4 [tensorflow-hub]
#    ---------------------------------------- 4/4 [tensorflow-hub]
#
# Successfully installed numpy-2.1.3 tensorflow-2.20.0 tensorflow-hub-0.16.1 tf-keras-2.20.1

# %%
import tensorflow as tf
import tensorflow_hub as hub
import librosa
import numpy as np
import os

# Paths
  # Healthy_Control/ and Parkinson/
SR = 16000  # YAMNet sample rate
BATCH_SIZE = 16
EPOCHS = 10

# Load YAMNet from TF Hub
yamnet_model_handle = 'https://tfhub.dev/google/yamnet/1'
yamnet_model = hub.load(yamnet_model_handle)

# Helper: extract embeddings from YAMNet
def extract_embedding(waveform):
    """Returns embeddings for the audio waveform using YAMNet"""
    scores, embeddings, spectrogram = yamnet_model(waveform)
    return embeddings  # shape: (num_patches, 1024)
# Out:
# C:\Users\Felix\anaconda3\Lib\site-packages\tensorflow_hub\__init__.py:61: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import parse_version
# WARNING:tensorflow:From C:\Users\Felix\anaconda3\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Felix\anaconda3\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From C:\Users\Felix\anaconda3\Lib\site-packages\tensorflow_hub\resolver.py:120: The name tf.gfile.MakeDirs is deprecated. Please use tf.io.gfile.makedirs instead.
# WARNING:tensorflow:From C:\Users\Felix\anaconda3\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.
# WARNING:tensorflow:From C:\Users\Felix\anaconda3\Lib\site-packages\tensorflow_hub\module_v2.py:126: The name tf.saved_model.load_v2 is deprecated. Please use tf.compat.v2.saved_model.load instead.

# %% [markdown]
# ### DATA LOADING

# %%
# Load your audio dataset and labels
DATASET_DIR = "PARK_DATA"
def load_dataset(dataset_dir):
    X = []
    y = []
    label_map = {'HC_segments': 0, 'PD_segments': 1}
    for label_name, label_id in label_map.items():
        folder = os.path.join(dataset_dir, label_name)
        for fname in os.listdir(folder):
            if not fname.endswith('.wav'):
                continue
            fpath = os.path.join(folder, fname)
            waveform, _ = librosa.load(fpath, sr=SR, mono=True)
            embedding = extract_embedding(waveform)
            X.append(embedding)
            y.append(np.full((embedding.shape[0],), label_id))  # one label per frame
    X = np.concatenate(X, axis=0)
    y = np.concatenate(y, axis=0)
    return X, y

print("Extracting embeddings...")
X, y = load_dataset(DATASET_DIR)
print("Embedding shape:", X.shape)
# Out:
# Extracting embeddings...
# Embedding shape: (6956, 1024)

# %% [markdown]
# ### MODEL TRAINING

# %%
# Build a simple classifier on top
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1024,)),  # YAMNet embeddings
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train
model.fit(X, y, batch_size=BATCH_SIZE, epochs=30, validation_split=0.2)

# Save for mobile deployment
model.save("yamnet_parkinsons_classifier.h5")
# Out:
# Epoch 1/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7761 - loss: 0.5182 - val_accuracy: 0.2730 - val_loss: 1.4785
# Epoch 2/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8145 - loss: 0.4376 - val_accuracy: 0.3455 - val_loss: 1.4671
# Epoch 3/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8242 - loss: 0.4134 - val_accuracy: 0.3585 - val_loss: 1.3068
# Epoch 4/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8280 - loss: 0.3884 - val_accuracy: 0.3182 - val_loss: 1.3881
# Epoch 5/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8427 - loss: 0.3601 - val_accuracy: 0.4684 - val_loss: 1.0886
# Epoch 6/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8456 - loss: 0.3547 - val_accuracy: 0.4181 - val_loss: 1.2544
# Epoch 7/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8508 - loss: 0.3418 - val_accuracy: 0.4310 - val_loss: 1.1836
# Epoch 8/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8562 - loss: 0.3385 - val_accuracy: 0.3506 - val_loss: 1.5495
# Epoch 9/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8666 - loss: 0.3137 - val_accuracy: 0.5065 - val_loss: 1.0756
# Epoch 10/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8693 - loss: 0.3103 - val_accuracy: 0.3721 - val_loss: 1.5336
# Epoch 11/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8753 - loss: 0.2996 - val_accuracy: 0.4282 - val_loss: 1.4028
# Epoch 12/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8801 - loss: 0.2849 - val_accuracy: 0.5158 - val_loss: 1.1019
# Epoch 13/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8792 - loss: 0.2831 - val_accuracy: 0.3355 - val_loss: 1.6577
# Epoch 14/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8826 - loss: 0.2696 - val_accuracy: 0.5661 - val_loss: 1.0347
# Epoch 15/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8893 - loss: 0.2646 - val_accuracy: 0.3657 - val_loss: 1.8275
# Epoch 16/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8954 - loss: 0.2511 - val_accuracy: 0.3951 - val_loss: 1.6852
# Epoch 17/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8970 - loss: 0.2458 - val_accuracy: 0.4533 - val_loss: 1.5104
# Epoch 18/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9069 - loss: 0.2360 - val_accuracy: 0.4009 - val_loss: 1.7809
# Epoch 19/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9058 - loss: 0.2291 - val_accuracy: 0.4066 - val_loss: 1.9044
# Epoch 20/20
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9121 - loss: 0.2162 - val_accuracy: 0.5079 - val_loss: 1.4129
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import os
import random
import numpy as np
import librosa
from sklearn.metrics import accuracy_score

# ----------------------------
# CONFIG
# ----------------------------
DATASET_DIR = "PARK_DATA"  # contains Healthy_Control/ and Parkinson/
SR = 16000  # YAMNet sample rate
BATCH_SIZE = 16
EPOCHS = 10
TEST_SPLIT = 0.1
VAL_SPLIT = 0.1
RANDOM_SEED = 42

# ----------------------------
# LOAD YAMNET
# ----------------------------
yamnet_model_handle = 'https://tfhub.dev/google/yamnet/1'
yamnet_model = hub.load(yamnet_model_handle)

def extract_embedding(waveform):
    """Return embeddings from YAMNet for a waveform"""
    scores, embeddings, spectrogram = yamnet_model(waveform)
    return embeddings.numpy()  # shape: (num_patches, 1024)

# ----------------------------
# LOAD AUDIO FILES & SPLIT
# ----------------------------
label_map = {'HC_segments': 0, 'PD_segments': 1}

# Collect files
all_files = []
for label_name, label_id in label_map.items():
    folder = os.path.join(DATASET_DIR, label_name)
    for fname in os.listdir(folder):
        if fname.endswith('.wav'):
            all_files.append((os.path.join(folder, fname), label_id))

# Shuffle
random.seed(RANDOM_SEED)
random.shuffle(all_files)

# Split
num_total = len(all_files)
num_test = int(TEST_SPLIT * num_total)
num_val = int(VAL_SPLIT * num_total)
num_train = num_total - num_val - num_test

train_files = all_files[:num_train]
val_files = all_files[num_train:num_train+num_val]
test_files = all_files[num_train+num_val:]

print(f"Train: {len(train_files)}, Val: {len(val_files)}, Test: {len(test_files)}")

# ----------------------------
# HELPER: Prepare data per file
# ----------------------------
def prepare_data(file_list):
    X = []
    y = []
    for fpath, label_id in file_list:
        waveform, _ = librosa.load(fpath, sr=SR, mono=True)
        embedding = extract_embedding(waveform)  # (num_patches, 1024)
        X.append(embedding)
        y.append(np.full((embedding.shape[0],), label_id))
    X = np.concatenate(X, axis=0)
    y = np.concatenate(y, axis=0)
    return X, y

# ----------------------------
X_train, y_train = prepare_data(train_files)
X_val, y_val = prepare_data(val_files)

# ----------------------------
# SAVE MODEL
# ----------------------------
# Out:
# Train: 44, Val: 5, Test: 5
# Epoch 1/10
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.7175 - loss: 0.5826 - val_accuracy: 0.5335 - val_loss: 0.8082
# Epoch 2/10
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7702 - loss: 0.4897 - val_accuracy: 0.5296 - val_loss: 0.8508
# Epoch 3/10
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7886 - loss: 0.4618 - val_accuracy: 0.5112 - val_loss: 0.9076
# Epoch 4/10
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7931 - loss: 0.4421 - val_accuracy: 0.4060 - val_loss: 1.1606
# Epoch 5/10
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8094 - loss: 0.4165 - val_accuracy: 0.5821 - val_loss: 0.7904
# Epoch 6/10
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8163 - loss: 0.4008 - val_accuracy: 0.6347 - val_loss: 0.7060
# Epoch 7/10
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8337 - loss: 0.3823 - val_accuracy: 0.3903 - val_loss: 1.2194
# Epoch 8/10
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.8297 - loss: 0.3774 - val_accuracy: 0.5821 - val_loss: 0.7923
# Epoch 9/10
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8367 - loss: 0.3705 - val_accuracy: 0.5558 - val_loss: 0.8717
# Epoch 10/10
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8468 - loss: 0.3562 - val_accuracy: 0.5953 - val_loss: 0.8768
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# ✅ File-level Validation Accuracy: 0.8000
# ✅ File-level Test Accuracy: 0.8000

# %%
# TRAINING
# ----------------------------


model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1024,)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    batch_size=BATCH_SIZE,
    epochs=30
)
# Out:
# Epoch 1/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - accuracy: 0.7231 - loss: 0.5761 - val_accuracy: 0.5913 - val_loss: 0.7113
# Epoch 2/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7663 - loss: 0.4973 - val_accuracy: 0.5138 - val_loss: 0.8846
# Epoch 3/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7839 - loss: 0.4545 - val_accuracy: 0.5821 - val_loss: 0.7591
# Epoch 4/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7956 - loss: 0.4353 - val_accuracy: 0.3876 - val_loss: 1.1575
# Epoch 5/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8078 - loss: 0.4169 - val_accuracy: 0.5230 - val_loss: 0.8827
# Epoch 6/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8191 - loss: 0.3946 - val_accuracy: 0.5558 - val_loss: 0.9115
# Epoch 7/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8236 - loss: 0.3883 - val_accuracy: 0.4967 - val_loss: 0.9260
# Epoch 8/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8303 - loss: 0.3768 - val_accuracy: 0.6702 - val_loss: 0.6510
# Epoch 9/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8407 - loss: 0.3639 - val_accuracy: 0.5414 - val_loss: 0.8889
# Epoch 10/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8420 - loss: 0.3592 - val_accuracy: 0.6084 - val_loss: 0.9017
# Epoch 11/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8490 - loss: 0.3457 - val_accuracy: 0.4442 - val_loss: 1.2355
# Epoch 12/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8531 - loss: 0.3339 - val_accuracy: 0.5230 - val_loss: 1.0078
# Epoch 13/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8540 - loss: 0.3277 - val_accuracy: 0.6137 - val_loss: 0.8652
# Epoch 14/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8671 - loss: 0.3131 - val_accuracy: 0.6163 - val_loss: 0.8999
# Epoch 15/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8736 - loss: 0.3027 - val_accuracy: 0.5085 - val_loss: 1.1542
# Epoch 16/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8731 - loss: 0.3059 - val_accuracy: 0.6032 - val_loss: 0.9195
# Epoch 17/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8833 - loss: 0.2843 - val_accuracy: 0.6084 - val_loss: 0.9279
# Epoch 18/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8901 - loss: 0.2770 - val_accuracy: 0.5900 - val_loss: 0.9907
# Epoch 19/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8912 - loss: 0.2680 - val_accuracy: 0.5414 - val_loss: 1.1657
# Epoch 20/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8946 - loss: 0.2637 - val_accuracy: 0.5953 - val_loss: 1.1182
# Epoch 21/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8968 - loss: 0.2610 - val_accuracy: 0.6413 - val_loss: 0.8202
# Epoch 22/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9015 - loss: 0.2435 - val_accuracy: 0.6583 - val_loss: 0.9559
# Epoch 23/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9018 - loss: 0.2411 - val_accuracy: 0.6662 - val_loss: 0.8335
# Epoch 24/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9087 - loss: 0.2221 - val_accuracy: 0.5480 - val_loss: 1.3463
# Epoch 25/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9060 - loss: 0.2265 - val_accuracy: 0.6373 - val_loss: 0.9526
# Epoch 26/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9150 - loss: 0.2154 - val_accuracy: 0.5848 - val_loss: 1.1708
# Epoch 27/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9159 - loss: 0.2107 - val_accuracy: 0.6399 - val_loss: 1.0389
# Epoch 28/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9209 - loss: 0.1978 - val_accuracy: 0.6163 - val_loss: 1.1664
# Epoch 29/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9274 - loss: 0.1945 - val_accuracy: 0.6491 - val_loss: 1.1520
# Epoch 30/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9254 - loss: 0.1865 - val_accuracy: 0.5900 - val_loss: 1.2293

# %%
# ----------------------------
# EVALUATION PER AUDIO FILE
# ----------------------------
def evaluate_per_file(model, file_list):
    y_true = []
    y_pred = []
    for fpath, label_id in file_list:
        waveform, _ = librosa.load(fpath, sr=SR, mono=True)
        embedding = extract_embedding(waveform)
        preds = model.predict(embedding)
        file_pred = float(np.mean(preds))  # aggregate over patches
        y_pred.append(int(file_pred >= 0.5))
        y_true.append(label_id)
    acc = accuracy_score(y_true, y_pred)
    return acc

test_acc = evaluate_per_file(model, test_files)
val_acc = evaluate_per_file(model, val_files)

print(f"✅ File-level Validation Accuracy: {val_acc:.4f}")
print(f"✅ File-level Test Accuracy: {test_acc:.4f}")
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ✅ File-level Validation Accuracy: 0.8000
# ✅ File-level Test Accuracy: 0.8000

# %%
# ----------------------------
DATASET_DIR = "PARK_DATA"  # contains Healthy_Control/ and Parkinson/
SR = 16000  # YAMNet sample rate
BATCH_SIZE = 16
EPOCHS = 30
TEST_SPLIT = 0.1
VAL_SPLIT = 0.1
RANDOM_SEED = 42

# ----------------------------
# LOAD YAMNET
# ----------------------------

def extract_embedding(waveform):
    """Return embeddings from YAMNet for a waveform"""
    scores, embeddings, spectrogram = yamnet_model(waveform)
    return embeddings.numpy()  # shape: (num_patches, 1024)

# ----------------------------
# LOAD AUDIO FILES & SPLIT
# ----------------------------
label_map = {'HC_segments': 0, 'PD_segments': 1}

# Collect files
all_files = []
for label_name, label_id in label_map.items():
    folder = os.path.join(DATASET_DIR, label_name)
    for fname in os.listdir(folder):
        if fname.endswith('.wav'):
            all_files.append((os.path.join(folder, fname), label_id))

# Shuffle
random.seed(RANDOM_SEED)
random.shuffle(all_files)

# Split
num_total = len(all_files)
num_test = int(TEST_SPLIT * num_total)
num_val = int(VAL_SPLIT * num_total)
num_train = num_total - num_val - num_test

train_files = all_files[:num_train]
val_files = all_files[num_train:num_train+num_val]
test_files = all_files[num_train+num_val:]

print(f"Train: {len(train_files)}, Val: {len(val_files)}, Test: {len(test_files)}")

# ----------------------------
# HELPER: Prepare embeddings per file
# ----------------------------
def prepare_embeddings(file_list):
    X_list, y_list, file_lengths = [], [], []
    for fpath, label_id in file_list:
        waveform, _ = librosa.load(fpath, sr=SR, mono=True)
        embeddings = extract_embedding(waveform)  # (num_patches, 1024)
        X_list.append(embeddings)
        y_list.append(np.full((embeddings.shape[0],), label_id))
        file_lengths.append(embeddings.shape[0])
    X = np.concatenate(X_list, axis=0)
    y = np.concatenate(y_list, axis=0)
    return X, y, file_lengths
X_train, y_train, train_lengths = prepare_embeddings(train_files)
X_val, y_val, val_lengths = prepare_embeddings(val_files)
# ----------------------------
# BUILD MODEL
# ----------------------------

# ----------------------------
# Out:
# Train: 44, Val: 5, Test: 5

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1024,)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# ----------------------------
# TRAIN
# ----------------------------


history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    batch_size=BATCH_SIZE,
    epochs=EPOCHS
)
# Out:
# Epoch 1/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7177 - loss: 0.5899 - val_accuracy: 0.6255 - val_loss: 0.7361
# Epoch 2/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7648 - loss: 0.4972 - val_accuracy: 0.5072 - val_loss: 0.8426
# Epoch 3/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7825 - loss: 0.4588 - val_accuracy: 0.5204 - val_loss: 0.8041
# Epoch 4/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.7923 - loss: 0.4403 - val_accuracy: 0.5913 - val_loss: 0.7421
# Epoch 5/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8064 - loss: 0.4249 - val_accuracy: 0.6018 - val_loss: 0.7281
# Epoch 6/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8164 - loss: 0.4019 - val_accuracy: 0.5401 - val_loss: 0.8518
# Epoch 7/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8243 - loss: 0.3921 - val_accuracy: 0.5401 - val_loss: 0.8934
# Epoch 8/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.8287 - loss: 0.3854 - val_accuracy: 0.5650 - val_loss: 0.8802
# Epoch 9/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8344 - loss: 0.3724 - val_accuracy: 0.5007 - val_loss: 1.0016
# Epoch 10/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8465 - loss: 0.3574 - val_accuracy: 0.4717 - val_loss: 1.1738
# Epoch 11/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8359 - loss: 0.3567 - val_accuracy: 0.5269 - val_loss: 0.9619
# Epoch 12/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8542 - loss: 0.3383 - val_accuracy: 0.6518 - val_loss: 0.7475
# Epoch 13/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8601 - loss: 0.3291 - val_accuracy: 0.5164 - val_loss: 0.9907
# Epoch 14/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8621 - loss: 0.3191 - val_accuracy: 0.5926 - val_loss: 0.9504
# Epoch 15/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8623 - loss: 0.3140 - val_accuracy: 0.6439 - val_loss: 0.8619
# Epoch 16/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8725 - loss: 0.3032 - val_accuracy: 0.6557 - val_loss: 0.8182
# Epoch 17/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8718 - loss: 0.3012 - val_accuracy: 0.5322 - val_loss: 1.0929
# Epoch 18/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8837 - loss: 0.2792 - val_accuracy: 0.6307 - val_loss: 0.8897
# Epoch 19/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8883 - loss: 0.2775 - val_accuracy: 0.5848 - val_loss: 0.9806
# Epoch 20/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8936 - loss: 0.2659 - val_accuracy: 0.6689 - val_loss: 0.8340
# Epoch 21/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8982 - loss: 0.2574 - val_accuracy: 0.6150 - val_loss: 0.9775
# Epoch 22/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8986 - loss: 0.2464 - val_accuracy: 0.5900 - val_loss: 0.9833
# Epoch 23/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9017 - loss: 0.2440 - val_accuracy: 0.5782 - val_loss: 1.0972
# Epoch 24/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9065 - loss: 0.2354 - val_accuracy: 0.5677 - val_loss: 1.1181
# Epoch 25/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9114 - loss: 0.2244 - val_accuracy: 0.5690 - val_loss: 1.1510
# Epoch 26/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9157 - loss: 0.2128 - val_accuracy: 0.6189 - val_loss: 1.1081
# Epoch 27/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9193 - loss: 0.2081 - val_accuracy: 0.5769 - val_loss: 1.1416
# Epoch 28/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9191 - loss: 0.2046 - val_accuracy: 0.6032 - val_loss: 1.1259
# Epoch 29/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9261 - loss: 0.1940 - val_accuracy: 0.5742 - val_loss: 1.2454
# Epoch 30/30
# 348/348 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9261 - loss: 0.1876 - val_accuracy: 0.6347 - val_loss: 1.0626

# %%
# EVALUATE PER AUDIO FILE
# ----------------------------
def evaluate_per_file(model, file_list):
    y_true, y_pred = [], []
    for fpath, label_id in file_list:
        waveform, _ = librosa.load(fpath, sr=SR, mono=True)
        embeddings = extract_embedding(waveform)
        preds = model.predict(embeddings)
        file_pred = float(np.mean(preds))  # aggregate predictions per file
        y_pred.append(int(file_pred >= 0.5))
        y_true.append(label_id)
    acc = accuracy_score(y_true, y_pred)
    return acc

train_acc_file = evaluate_per_file(model, train_files)
val_acc_file = evaluate_per_file(model, val_files)
test_acc_file = evaluate_per_file(model, test_files)

print(f"✅ File-level Train Accuracy: {train_acc_file:.4f}")
print(f"✅ File-level Validation Accuracy: {val_acc_file:.4f}")
print(f"✅ File-level Test Accuracy: {test_acc_file:.4f}")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# ✅ File-level Train Accuracy: 1.0000
# ✅ File-level Validation Accuracy: 0.8000
# ✅ File-level Test Accuracy: 0.8000

# %%
model.save("yamnet_parkinsons_classifier.h5")
print("Model saved! Ready for TFLite conversion.")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved! Ready for TFLite conversion.

# %%
model = tf.keras.models.load_model("yamnet_parkinsons_classifier.h5")

# Convert to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TFLite model
with open("yamnet_parkinsons_classifier.tflite", "wb") as f:
    f.write(tflite_model)

print("✅ TFLite model saved (no quantization).")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: C:\Users\Felix\AppData\Local\Temp\tmps2zawer6\assets
# INFO:tensorflow:Assets written to: C:\Users\Felix\AppData\Local\Temp\tmps2zawer6\assets
# Saved artifact at 'C:\Users\Felix\AppData\Local\Temp\tmps2zawer6'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 1024), dtype=tf.float32, name='input_layer_5')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   2658929628304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2658929636944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2658929630992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2658929627728: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ TFLite model saved (no quantization).

# %%
import tensorflow as tf
import tensorflow_hub as hub

# Load YAMNet
yamnet_model = hub.load('https://tfhub.dev/google/yamnet/1')

# Function to get embeddings from waveform
def yamnet_embeddings(waveform):
    scores, embeddings, spectrogram = yamnet_model(waveform)
    return embeddings

# Create a Keras model for TFLite conversion
class YAMNetEmbeddingModel(tf.keras.Model):
    def __init__(self, yamnet):
        super(YAMNetEmbeddingModel, self).__init__()
        self.yamnet = yamnet

    @tf.function(input_signature=[tf.TensorSpec(shape=[None], dtype=tf.float32)])
    def call(self, waveform):
        _, embeddings, _ = self.yamnet(waveform)
        return embeddings

# Instantiate
model = YAMNetEmbeddingModel(yamnet_model)

# Convert to TFLite
converter = tf.lite.TFLiteConverter.from_concrete_functions([model.call.get_concrete_function()])
converter.optimizations = [tf.lite.Optimize.DEFAULT]  # Optional: optimize size/performance
tflite_model = converter.convert()

# Save TFLite model
with open('yamnet_embeddings.tflite', 'wb') as f:
    f.write(tflite_model)

print("✅ YAMNet embeddings TFLite model saved!")
# Out:
# WARNING:absl:Please consider providing the trackable_obj argument in the from_concrete_functions. Providing without the trackable_obj argument is deprecated and it will use the deprecated conversion path.
# ✅ YAMNet embeddings TFLite model saved!
